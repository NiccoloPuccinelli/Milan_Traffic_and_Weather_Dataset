# %% [markdown]
# # Data acquisition

# %%
import requests
from apscheduler.schedulers.blocking import BlockingScheduler
from tzlocal import get_localzone
import json



# Schema generale:
# 1. Richiesta API tramite GET
# 2. Recupero del body della richiesta in formato json
#    2.1. Recupero dell'header della richiesta per ottenere data e ora (solo per traffico) 
# 3. Scrittura file


# Codice da eseguire solo una volta: crea i json la prima volta in modo da poter fare append successivamente

# ----- NAVIGLI -----

 
# VIA GIOSUE' CARDUCCI
 
response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.46539%2C9.17516&unit=KMPH&openLr=false&key=lzXFwcI1wSRpMt0uVxrJceiblqrBUiYJ')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Navigli/Via_Carducci.json', 'w') as f:
  f.write(jsonobj)

# La data del traffico è nell'header
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Navigli/Via_Carducci_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
  
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.46539&lon=9.17516&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Navigli/Via_Carducci.json', 'w') as f:
  f.write(jsonobj)
   
 
# VIA EDMONDO DE AMICIS
 
response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45948%2C9.17651&unit=KMPH&openLr=false&key=lzXFwcI1wSRpMt0uVxrJceiblqrBUiYJ')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Navigli/Via_De_Amicis.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Navigli/Via_De_Amicis_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')

response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45948&lon=9.17651&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Navigli/Via_De_Amicis.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIA MOLINO DELLE ARMI

response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45681%2C9.18433&unit=KMPH&openLr=false&key=lzXFwcI1wSRpMt0uVxrJceiblqrBUiYJ')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Navigli/Via_Delle_Armi.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Navigli/Via_Delle_Armi_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')

response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45681&lon=9.18433&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Navigli/Via_Delle_Armi.json', 'w') as f:
   f.write(jsonobj)
 
 
# VIA SANTA SOFIA
 
response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45707%2C9.19038&unit=KMPH&openLr=false&key=lzXFwcI1wSRpMt0uVxrJceiblqrBUiYJ')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Navigli/Via_Santa_Sofia.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Navigli/Via_Santa_Sofia_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
 
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45707&lon=9.19038&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Navigli/Via_Santa_Sofia.json', 'w') as f:
  f.write(jsonobj)
   
 
# VIA FRANCESCO SFORZA

response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.46041%2C9.19601&unit=KMPH&openLr=false&key=lzXFwcI1wSRpMt0uVxrJceiblqrBUiYJ')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Navigli/Via_Sforza.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Navigli/Via_Sforza_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')

response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.46041&lon=9.19601&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Navigli/Via_Sforza.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIA UBERTO VISCONTI DI MODRONE + VIA SAN DAMIANO

response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.465281%2C9.200260&unit=KMPH&openLr=false&key=lzXFwcI1wSRpMt0uVxrJceiblqrBUiYJ')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Navigli/Vie_Visconti_San_Damiano.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Navigli/Vie_Visconti_San_Damiano_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')

response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.465281&lon=9.200260&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Navigli/Vie_Visconti_San_Damiano.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIA SENATO

response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.47070%2C9.19732&unit=KMPH&openLr=false&key=OdnDWG7YVGi3dATSc1n1CMexGhWGrJ6C')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Navigli/Via_Senato.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Navigli/Via_Senato_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
  
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.47070&lon=9.19732&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Navigli/Via_Senato.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIA FATEBENEFRATELLI

response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.47327%2C9.19114&unit=KMPH&openLr=false&key=OdnDWG7YVGi3dATSc1n1CMexGhWGrJ6C')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Navigli/Via_Fatebenefratelli.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Navigli/Via_Fatebenefratelli_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')

response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.47327&lon=9.19114&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Navigli/Via_Fatebenefratelli.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIA PONTACCIO

response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.472688%2C9.193423&unit=KMPH&openLr=false&key=OdnDWG7YVGi3dATSc1n1CMexGhWGrJ6C')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Navigli/Via_Pontaccio.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Navigli/Via_Pontaccio_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')

response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.472688&lon=9.193423&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Navigli/Via_Pontaccio.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIA TIVOLI
 
response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.472656%2C9.186141&unit=KMPH&openLr=false&key=OdnDWG7YVGi3dATSc1n1CMexGhWGrJ6C')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Navigli/Via_Tivoli.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Navigli/Via_Tivoli_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
 
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.472656&lon=9.186141&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Navigli/Via_Tivoli.json', 'w') as f:
  f.write(jsonobj)
   
   
# PIAZZA CASTELLO (FORO BUONAPARTE) 
 
response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.467896%2C9.181429&unit=KMPH&openLr=false&key=OdnDWG7YVGi3dATSc1n1CMexGhWGrJ6C')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Navigli/Piazza_Castello.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Navigli/Piazza_Castello_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
 
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.467896&lon=9.181429&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Navigli/Piazza_Castello.json', 'w') as f:
  f.write(jsonobj)
   
   
# ----- BASTIONI -----
 
 
# VIALE DI PORTA VERCELLINA
 
response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.46378%2C9.16524&unit=KMPH&openLr=false&key=OdnDWG7YVGi3dATSc1n1CMexGhWGrJ6C')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Di_Porta_Vercellina.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Di_Porta_Vercellina_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
   
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.46378&lon=9.16524&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Bastioni/Viale_Di_Porta_Vercellina.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIALE PAPINIANO 
 
response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.458872%2C9.168376&unit=KMPH&openLr=false&key=zpgTPCnQXjBt82C1K7Ium1uF0w6u7Ih6')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Papiniano.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Papiniano_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
 
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.458872&lon=9.168376&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Bastioni/Viale_Papiniano.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIALE GABRIELE D'ANNUNZIO
 
response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.454563%2C9.175085&unit=KMPH&openLr=false&key=zpgTPCnQXjBt82C1K7Ium1uF0w6u7Ih6')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Bastioni/Viale_D_Annunzio.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Bastioni/Viale_D_Annunzio_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
 
  
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.454563&lon=9.175085&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Bastioni/Viale_D_Annunzio.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIALE GIAN GALEAZZO
 
response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45333%2C9.18326&unit=KMPH&openLr=false&key=zpgTPCnQXjBt82C1K7Ium1uF0w6u7Ih6')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Gian_Galeazzo.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Gian_Galeazzo_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
 
  
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45333&lon=9.18326&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Bastioni/Viale_Gian_Galeazzo.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIALE BEATRICE D'ESTE
 
response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45225%2C9.19149&unit=KMPH&openLr=false&key=zpgTPCnQXjBt82C1K7Ium1uF0w6u7Ih6')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Bastioni/Viale_D_Este.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Bastioni/Viale_D_Este_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
 
   
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45225&lon=9.19149&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Bastioni/Viale_D_Este.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIALE ANGELO FILIPPETTI

response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45207%2C9.19843&unit=KMPH&openLr=false&key=zpgTPCnQXjBt82C1K7Ium1uF0w6u7Ih6')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Filippetti.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Filippetti_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
 
  
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45207&lon=9.19843&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Bastioni/Viale_Filippetti.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIALE EMILIO CALDARA

response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45501,9.20303&unit=KMPH&openLr=false&key=zpgTPCnQXjBt82C1K7Ium1uF0w6u7Ih6')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Caldara.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Caldara_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
 
  
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45501&lon=9.20303&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Bastioni/Viale_Caldara.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIALE REGINA MARGHERITA

response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45982%2C9.20626&unit=KMPH&openLr=false&key=uBHDV4cGrhjgQ5d46LJr3X0oIe8QfNJl')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Margherita.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Margherita_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
 
  
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45982&lon=9.20626&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Bastioni/Viale_Margherita.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIALE BIANCA MARIA + LUIGI MAJNO

response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.46539%2C9.20642&unit=KMPH&openLr=false&key=uBHDV4cGrhjgQ5d46LJr3X0oIe8QfNJl')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Maria_Majno.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Maria_Majno_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
 
  
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.46539&lon=9.20642&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Bastioni/Viale_Maria_Majno.json', 'w') as f:
  f.write(jsonobj)
   
   
# BASTIONI DI PORTA VENEZIA
 
response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.47524%2C9.20286&unit=KMPH&openLr=false&key=uBHDV4cGrhjgQ5d46LJr3X0oIe8QfNJl')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Bastioni/Bastioni_Porta_Venezia.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Bastioni/Bastioni_Porta_Venezia_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
 
   
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.47524&lon=9.20286&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Bastioni/Bastioni_Porta_Venezia.json', 'w') as f:
  f.write(jsonobj)
   
   
# VIALE MONTE SANTO
 
response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.47965%2C9.19438&unit=KMPH&openLr=false&key=uBHDV4cGrhjgQ5d46LJr3X0oIe8QfNJl')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Monte_Santo.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Bastioni/Viale_Monte_Santo.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
 
   
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.47965&lon=9.19438&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Bastioni/Viale_Monte_Santo.json', 'w') as f:
  f.write(jsonobj)
   
   
# BASTIONI DI PORTA NUOVA + VIALE CRISPI
 
response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.48104%2C9.18431&unit=KMPH&openLr=false&key=uBHDV4cGrhjgQ5d46LJr3X0oIe8QfNJl')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Bastioni/Bastioni_Porta_Nuova_Viale_Crispi.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Bastioni/Bastioni_Porta_Nuova_Viale_Crispi_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')
 
   
response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.48104&lon=9.18431&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Bastioni/Bastioni_Porta_Nuova_Viale_Crispi.json', 'w') as f:
  f.write(jsonobj)
   
   
# BASTIONI DI PORTA VOLTA
 
response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.47991%2C9.18216&unit=KMPH&openLr=false&key=uBHDV4cGrhjgQ5d46LJr3X0oIe8QfNJl')
jsonobj = data.response_API.text
with open('DataMan/Data/Traffic Data/Bastioni/Bastioni_Porta_Volta.json', 'w') as f:
  f.write(jsonobj)
jsonhead = {'date':response_API.headers['date']}
with open('DataMan/Data/Traffic Data/Bastioni/Bastioni_Porta_Volta_Header.json', 'w') as f:
  f.write('"'+str(jsonhead)+'"')

response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.47991&lon=9.18216&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
jsonobj = data.response_API.text
with open('DataMan/Data/Weather Data/Bastioni/Bastioni_Porta_Volta.json', 'w') as f:
  f.write(jsonobj) 



# Job eseguito ogni 10 minuti: append ai json già esistenti
# Dati dal 28-12-21 al 10-01-22 (compresi)

tz = get_localzone()

sched = BlockingScheduler()
@sched.scheduled_job('interval', minutes = 10, start_date = "2021-12-28 00:00:00", end_date = "2022-01-11 00:00:00", timezone = tz)
def timed_job():
    
    print('Job started')


    # ----- NAVIGLI -----

 
    # VIA GIOSUE' CARDUCCI
    
    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.46539%2C9.17516&unit=KMPH&openLr=false&key=lzXFwcI1wSRpMt0uVxrJceiblqrBUiYJ')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Navigli/Via_Carducci.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Navigli/Via_Carducci_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
      
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.46539&lon=9.17516&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Navigli/Via_Carducci.json', 'a') as f:
      f.write(jsonobj)
      
    
    # VIA EDMONDO DE AMICIS
    
    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45948%2C9.17651&unit=KMPH&openLr=false&key=lzXFwcI1wSRpMt0uVxrJceiblqrBUiYJ')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Navigli/Via_De_Amicis.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Navigli/Via_De_Amicis_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')

    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45948&lon=9.17651&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Navigli/Via_De_Amicis.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIA MOLINO DELLE ARMI

    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45681%2C9.18433&unit=KMPH&openLr=false&key=lzXFwcI1wSRpMt0uVxrJceiblqrBUiYJ')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Navigli/Via_Delle_Armi.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Navigli/Via_Delle_Armi_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')

    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45681&lon=9.18433&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Navigli/Via_Delle_Armi.json', 'a') as f:
      f.write(jsonobj)
    
    
    # VIA SANTA SOFIA
    
    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45707%2C9.19038&unit=KMPH&openLr=false&key=lzXFwcI1wSRpMt0uVxrJceiblqrBUiYJ')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Navigli/Via_Santa_Sofia.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Navigli/Via_Santa_Sofia_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
    
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45707&lon=9.19038&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Navigli/Via_Santa_Sofia.json', 'a') as f:
      f.write(jsonobj)
      
    
    # VIA FRANCESCO SFORZA

    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.46041%2C9.19601&unit=KMPH&openLr=false&key=lzXFwcI1wSRpMt0uVxrJceiblqrBUiYJ')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Navigli/Via_Sforza.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Navigli/Via_Sforza_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')

    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.46041&lon=9.19601&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Navigli/Via_Sforza.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIA UBERTO VISCONTI DI MODRONE + VIA SAN DAMIANO

    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.465281%2C9.200260&unit=KMPH&openLr=false&key=lzXFwcI1wSRpMt0uVxrJceiblqrBUiYJ')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Navigli/Vie_Visconti_San_Damiano.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Navigli/Vie_Visconti_San_Damiano_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')

    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.465281&lon=9.200260&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Navigli/Vie_Visconti_San_Damiano.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIA SENATO

    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.47070%2C9.19732&unit=KMPH&openLr=false&key=OdnDWG7YVGi3dATSc1n1CMexGhWGrJ6C')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Navigli/Via_Senato.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Navigli/Via_Senato_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
      
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.47070&lon=9.19732&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Navigli/Via_Senato.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIA FATEBENEFRATELLI

    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.47327%2C9.19114&unit=KMPH&openLr=false&key=OdnDWG7YVGi3dATSc1n1CMexGhWGrJ6C')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Navigli/Via_Fatebenefratelli.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Navigli/Via_Fatebenefratelli_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')

    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.47327&lon=9.19114&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Navigli/Via_Fatebenefratelli.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIA PONTACCIO

    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.472688%2C9.193423&unit=KMPH&openLr=false&key=OdnDWG7YVGi3dATSc1n1CMexGhWGrJ6C')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Navigli/Via_Pontaccio.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Navigli/Via_Pontaccio_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')

    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.472688&lon=9.193423&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Navigli/Via_Pontaccio.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIA TIVOLI
    
    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.472656%2C9.186141&unit=KMPH&openLr=false&key=OdnDWG7YVGi3dATSc1n1CMexGhWGrJ6C')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Navigli/Via_Tivoli.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Navigli/Via_Tivoli_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
    
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.472656&lon=9.186141&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Navigli/Via_Tivoli.json', 'a') as f:
      f.write(jsonobj)
      
      
    # PIAZZA CASTELLO (FORO BUONAPARTE) 
    
    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.467896%2C9.181429&unit=KMPH&openLr=false&key=OdnDWG7YVGi3dATSc1n1CMexGhWGrJ6C')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Navigli/Piazza_Castello.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Navigli/Piazza_Castello_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
    
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.467896&lon=9.181429&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Navigli/Piazza_Castello.json', 'a') as f:
      f.write(jsonobj)
      
      
    # ----- BASTIONI -----
    
    
    # VIALE DI PORTA VERCELLINA
    
    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.46378%2C9.16524&unit=KMPH&openLr=false&key=OdnDWG7YVGi3dATSc1n1CMexGhWGrJ6C')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Di_Porta_Vercellina.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Di_Porta_Vercellina_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
      
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.46378&lon=9.16524&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Bastioni/Viale_Di_Porta_Vercellina.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIALE PAPINIANO 
    
    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.458872%2C9.168376&unit=KMPH&openLr=false&key=zpgTPCnQXjBt82C1K7Ium1uF0w6u7Ih6')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Papiniano.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Papiniano_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
    
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.458872&lon=9.168376&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Bastioni/Viale_Papiniano.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIALE GABRIELE D'ANNUNZIO
    
    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.454563%2C9.175085&unit=KMPH&openLr=false&key=zpgTPCnQXjBt82C1K7Ium1uF0w6u7Ih6')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_D_Annunzio.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_D_Annunzio_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
    
      
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.454563&lon=9.175085&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Bastioni/Viale_D_Annunzio.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIALE GIAN GALEAZZO
    
    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45333%2C9.18326&unit=KMPH&openLr=false&key=zpgTPCnQXjBt82C1K7Ium1uF0w6u7Ih6')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Gian_Galeazzo.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Gian_Galeazzo_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
    
      
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45333&lon=9.18326&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Bastioni/Viale_Gian_Galeazzo.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIALE BEATRICE D'ESTE
    
    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45225%2C9.19149&unit=KMPH&openLr=false&key=zpgTPCnQXjBt82C1K7Ium1uF0w6u7Ih6')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_D_Este.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_D_Este_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
    
      
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45225&lon=9.19149&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Bastioni/Viale_D_Este.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIALE ANGELO FILIPPETTI

    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45207%2C9.19843&unit=KMPH&openLr=false&key=zpgTPCnQXjBt82C1K7Ium1uF0w6u7Ih6')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Filippetti.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Filippetti_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
    
      
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45207&lon=9.19843&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Bastioni/Viale_Filippetti.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIALE EMILIO CALDARA

    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45501,9.20303&unit=KMPH&openLr=false&key=zpgTPCnQXjBt82C1K7Ium1uF0w6u7Ih6')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Caldara.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Caldara_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
    
      
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45501&lon=9.20303&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Bastioni/Viale_Caldara.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIALE REGINA MARGHERITA

    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.45982%2C9.20626&unit=KMPH&openLr=false&key=uBHDV4cGrhjgQ5d46LJr3X0oIe8QfNJl')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Margherita.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Margherita_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
    
      
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.45982&lon=9.20626&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Bastioni/Viale_Margherita.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIALE BIANCA MARIA + LUIGI MAJNO

    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.46539%2C9.20642&unit=KMPH&openLr=false&key=uBHDV4cGrhjgQ5d46LJr3X0oIe8QfNJl')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Maria_Majno.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Maria_Majno_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
    
      
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.46539&lon=9.20642&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Bastioni/Viale_Maria_Majno.json', 'a') as f:
      f.write(jsonobj)
      
      
    # BASTIONI DI PORTA VENEZIA
    
    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.47524%2C9.20286&unit=KMPH&openLr=false&key=uBHDV4cGrhjgQ5d46LJr3X0oIe8QfNJl')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Bastioni/Bastioni_Porta_Venezia.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Bastioni/Bastioni_Porta_Venezia_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
    
      
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.47524&lon=9.20286&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Bastioni/Bastioni_Porta_Venezia.json', 'a') as f:
      f.write(jsonobj)
      
      
    # VIALE MONTE SANTO
    
    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.47965%2C9.19438&unit=KMPH&openLr=false&key=uBHDV4cGrhjgQ5d46LJr3X0oIe8QfNJl')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Monte_Santo.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Bastioni/Viale_Monte_Santo.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
    
      
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.47965&lon=9.19438&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Bastioni/Viale_Monte_Santo.json', 'a') as f:
      f.write(jsonobj)
      
      
    # BASTIONI DI PORTA NUOVA + VIALE CRISPI
    
    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.48104%2C9.18431&unit=KMPH&openLr=false&key=uBHDV4cGrhjgQ5d46LJr3X0oIe8QfNJl')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Bastioni/Bastioni_Porta_Nuova_Viale_Crispi.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Bastioni/Bastioni_Porta_Nuova_Viale_Crispi_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')
    
      
    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.48104&lon=9.18431&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Bastioni/Bastioni_Porta_Nuova_Viale_Crispi.json', 'a') as f:
      f.write(jsonobj)
      
      
    # BASTIONI DI PORTA VOLTA
    
    response_API = requests.get('https://api.tomtom.com/traffic/services/4/flowSegmentData/relative0/10/json?point=45.47991%2C9.18216&unit=KMPH&openLr=false&key=uBHDV4cGrhjgQ5d46LJr3X0oIe8QfNJl')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Traffic Data/Bastioni/Bastioni_Porta_Volta.json', 'a') as f:
      f.write(jsonobj)
    jsonhead = {'date':response_API.headers['date']}
    with open('DataMan/Data/Traffic Data/Bastioni/Bastioni_Porta_Volta_Header.json', 'a') as f:
      f.write('"'+str(jsonhead)+'"')

    response_API = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=45.47991&lon=9.18216&appid=c13eb1c982e89381cfa9005af25d35f4&units=metric')
    jsonobj = data.response_API.text
    with open('DataMan/Data/Weather Data/Bastioni/Bastioni_Porta_Volta.json', 'a') as f:
      f.write(jsonobj) 
      
      
    print('Job finished')

sched.start()

# %% [markdown]
# # Data preparation

# %%
import json
import re
import pandas as pd
import numpy as np
from datetime import datetime, timedelta, date, time



# ----- TRAFFICO -----


# Liste coi nomi delle vie delle due circonvallazioni

bastioni = ['/Bastioni_Porta_Nuova_Viale_Crispi','/Bastioni_Porta_Venezia','/Bastioni_Porta_Volta','/Viale_Caldara',
          '/Viale_D_Annunzio','/Viale_D_Este','/Viale_Di_Porta_Vercellina','/Viale_Filippetti','/Viale_Gian_Galeazzo',
          '/Viale_Margherita','/Viale_Monte_Santo','/Viale_Papiniano','/Viale_Maria_Majno']
navigli = ['/Piazza_Castello','/Via_Carducci','/Via_De_Amicis','/Via_Delle_Armi','/Via_Fatebenefratelli','/Via_Pontaccio',
         '/Via_Santa_Sofia','/Via_Senato','/Via_Sforza','/Via_Tivoli','/Vie_Visconti_San_Damiano']


url_bastioni_flow = '/content/drive/MyDrive/DataMan/Data/Traffic Data/Circonvallazione Bastioni'
url_navigli_flow = '/content/drive/MyDrive/DataMan/Data/Traffic Data/Circonvallazione Navigli'

bastioni_dict_flow = {}
navigli_dict_flow = {}


# Apertura json

for street in bastioni:
    with open(url_bastioni_flow + street + '.json') as street_file:
        bastioni_dict_flow[street[1:]] = re.split(r'""+', street_file.read())

for street in navigli:
    with open(url_navigli_flow+street+'.json') as street_file:
        navigli_dict_flow[street[1:]] = re.split(r'""+', street_file.read())


# Il primo e l'ultimo elemento di ogni lista hanno un " di troppo: eliminiamolo

for street in bastioni:
     bastioni_dict_flow[street[1:]][0]=bastioni_dict_flow[street[1:]][0][1:]
     bastioni_dict_flow[street[1:]][-1]=bastioni_dict_flow[street[1:]][-1][:-1]

for street in navigli:
     navigli_dict_flow[street[1:]][0]=navigli_dict_flow[street[1:]][0][1:]
     navigli_dict_flow[street[1:]][-1]=navigli_dict_flow[street[1:]][-1][:-1]


# Dobbiamo rimpiazzare ' con " negli header per leggerli come json

for street in bastioni:
     l = len(bastioni_dict_flow[street[1:]])
     for i in range(int(l/2)):
         string = str(bastioni_dict_flow[street[1:]][2*i+1])
         string = re.sub(r"'", '"', string)
         bastioni_dict_flow[street[1:]][2*i+1] = string

for street in navigli:
     l = len(navigli_dict_flow[street[1:]])
     for i in range(int(l/2)):
         string = str(navigli_dict_flow[street[1:]][2*i+1])
         string = re.sub(r"'", '"', string)
         navigli_dict_flow[street[1:]][2*i+1] = string


# Identifichiamo ed eliminiamo gli elementi contenenti il body di richieste non andate a buon fine
'''
for street in bastioni:
    l = len(bastioni_dict_flow[street[1:]])
    for i in range(l):
      if('date' not in bastioni_dict_flow[street[1:]][i]):
        if('"currentSpeed"' not in bastioni_dict_flow[street[1:]][i]):
          print(street)
          print(bastioni_dict_flow[street[1:]][i])
          print(i)
        
for street in navigli:
    l = len(navigli_dict_flow[street[1:]])
    for i in range(l):
      if('date' not in navigli_dict_flow[street[1:]][i]):
        if('"currentSpeed"' not in navigli_dict_flow[street[1:]][i]):
          print(street)
          print(navigli_dict_flow[street[1:]][i])
          print(i)
'''

# Tutte le richieste sono andate a buon fine

# Ora possiamo leggere ogni elemento delle liste come json

bastioni_flow_json = {}
bastioni_date_json = {}

navigli_flow_json = {}
navigli_date_json = {}

for street in bastioni:
    l = len(bastioni_dict_flow[street[1:]])
    bastioni_flow_json[street[1:]] = []
    bastioni_date_json[street[1:]] = []
    for i in range(int(l/2)):
        bastioni_flow_json[street[1:]].append(json.loads(bastioni_dict_flow[street[1:]][2*i]))
        bastioni_date_json[street[1:]].append(json.loads(bastioni_dict_flow[street[1:]][2*i+1]))

for street in navigli:
    l = len(navigli_dict_flow[street[1:]])
    navigli_flow_json[street[1:]] = []
    navigli_date_json[street[1:]] = []
    for i in range(int(l/2)):
        navigli_flow_json[street[1:]].append(json.loads(navigli_dict_flow[street[1:]][2*i]))
        navigli_date_json[street[1:]].append(json.loads(navigli_dict_flow[street[1:]][2*i+1]))


# Associamo i json delle date ai json del traffico

for street in bastioni:
    l = len(bastioni_flow_json[street[1:]])
    for i in range(l):
        date_obj = datetime.strptime(bastioni_date_json[street[1:]][i]['date'], '%a, %d %b %Y %H:%M:%S %Z')
        date_obj = date_obj + timedelta(hours = 1)
        bastioni_flow_json[street[1:]][i]['date'] = pd.to_datetime(date_obj.timestamp(), unit = 's')

for street in navigli:
    l = len(navigli_flow_json[street[1:]])
    for i in range(l):
        date_obj = datetime.strptime(navigli_date_json[street[1:]][i]['date'], '%a, %d %b %Y %H:%M:%S %Z')
        date_obj = date_obj + timedelta(hours = 1)
        navigli_flow_json[street[1:]][i]['date'] = pd.to_datetime(date_obj.timestamp(), unit = 's')


# Eliminiamo l'elemento @version e rimpiazziamo le coordinate geografiche con i nomi delle vie

for street in bastioni:
    l = len(bastioni_flow_json[street[1:]])
    for i in range(l):
        del bastioni_flow_json[street[1:]][i]['flowSegmentData']['@version']
        del bastioni_flow_json[street[1:]][i]['flowSegmentData']['coordinates']
        bastioni_flow_json[street[1:]][i]['street'] = street[1:]

for street in navigli:
    l = len(navigli_flow_json[street[1:]])
    for i in range(l):
        del navigli_flow_json[street[1:]][i]['flowSegmentData']['@version']
        del navigli_flow_json[street[1:]][i]['flowSegmentData']['coordinates']
        navigli_flow_json[street[1:]][i]['street'] = street[1:]



# ----- METEO -----


url_bastioni_weather = '/content/drive/MyDrive/DataMan/Data/Weather Data/Circonvallazione Bastioni'
url_navigli_weather = '/content/drive/MyDrive/DataMan/Data/Weather Data/Circonvallazione Navigli'

bastioni_dict_weather = {}
navigli_dict_weather = {}


# Apertura json

for street in bastioni:
    with open(url_bastioni_weather + street + '.json') as street_file:
        bastioni_dict_weather[street[1:]] = re.split(r'""+', street_file.read())

for street in navigli:
    with open(url_navigli_weather + street + '.json') as street_file:
        navigli_dict_weather[street[1:]] = re.split(r'""+', street_file.read())


# Il primo e l'ultimo elemento di ogni lista hanno un " di troppo: eliminiamolo

for street in bastioni:
     bastioni_dict_weather[street[1:]][0] = bastioni_dict_weather[street[1:]][0][1:]
     bastioni_dict_weather[street[1:]][-1] = bastioni_dict_weather[street[1:]][-1][:-1]

for street in navigli:
     navigli_dict_weather[street[1:]][0] = navigli_dict_weather[street[1:]][0][1:]
     navigli_dict_weather[street[1:]][-1] = navigli_dict_weather[street[1:]][-1][:-1]


# Identifichiamo ed eliminiamo gli elementi contenenti il body di richieste non andate a buon fine
'''
for street in bastioni:
    l = len(bastioni_dict_weather[street[1:]])
    for i in range(l):
      if('"cod": 200' not in bastioni_dict_weather[street[1:]][i]):
        print(street)
        print(bastioni_dict_weather[street[1:]][i])
        print(i)
        
for street in navigli:
    l = len(navigli_dict_weather[street[1:]])
    for i in range(l):
      if('"cod": 200' not in navigli_dict_weather[street[1:]][i]):
        print(street)
        print(navigli_dict_weather[street[1:]][i])
        print(i)
'''

# Via Pontaccio: 969, Via Tivoli: 966 - Errore 400

del navigli_dict_weather['Via_Pontaccio'][969]
del navigli_dict_weather['Via_Tivoli'][966]


# Ora possiamo leggere ogni elemento delle liste come json 

bastioni_weather_json = {}
navigli_weather_json = {}

for street in bastioni:
    l = len(bastioni_dict_weather[street[1:]])
    bastioni_weather_json[street[1:]] = []
    for i in range(l):
        bastioni_weather_json[street[1:]].append(json.loads(bastioni_dict_weather[street[1:]][i]))

for street in navigli:
    l = len(navigli_dict_weather[street[1:]])
    navigli_weather_json[street[1:]] = []
    for i in range(l):
        navigli_weather_json[street[1:]].append(json.loads(navigli_dict_weather[street[1:]][i]))


# Eliminiamo le coordinate geografiche (rimpiazzate dai nomi delle vie nei dati del traffico) e
# convertiamo l'attributo dt (tempo in Unix time) in data (con lo stesso formato della data nel traffico)

for street in bastioni:
    l = len(bastioni_dict_weather[street[1:]])
    for i in range(l):
        bastioni_weather_json[street[1:]][i]['street'] = street[1:]
        del bastioni_weather_json[street[1:]][i]['coord']
        bastioni_weather_json[street[1:]][i]['lastUpdate'] = pd.to_datetime(bastioni_weather_json[street[1:]][i]['dt'], unit = 's') + timedelta(hours = 1)
        del bastioni_weather_json[street[1:]][i]['dt']
        bastioni_weather_json[street[1:]][i]['sys']['sunrise'] = pd.to_datetime(bastioni_weather_json[street[1:]][i]['sys']['sunrise'], unit = 's')
        bastioni_weather_json[street[1:]][i]['sys']['sunset'] = pd.to_datetime(bastioni_weather_json[street[1:]][i]['sys']['sunset'], unit = 's')
        bastioni_weather_json[street[1:]][i]['weather'] = bastioni_weather_json[street[1:]][i]['weather'][0]

for street in navigli:
    l = len(navigli_dict_weather[street[1:]])
    for i in range(l):
        navigli_weather_json[street[1:]][i]['street'] = street[1:]
        del navigli_weather_json[street[1:]][i]['coord']
        navigli_weather_json[street[1:]][i]['lastUpdate'] = pd.to_datetime(navigli_weather_json[street[1:]][i]['dt'], unit = 's') + timedelta(hours = 1)
        del navigli_weather_json[street[1:]][i]['dt']
        navigli_weather_json[street[1:]][i]['sys']['sunrise'] = pd.to_datetime(navigli_weather_json[street[1:]][i]['sys']['sunrise'], unit = 's')
        navigli_weather_json[street[1:]][i]['sys']['sunset'] = pd.to_datetime(navigli_weather_json[street[1:]][i]['sys']['sunset'], unit = 's')
        navigli_weather_json[street[1:]][i]['weather'] = navigli_weather_json[street[1:]][i]['weather'][0]


# Per vedere un esempio dei json
'''
print('Struttura json del traffico (Bastioni):')
print(bastioni_flow_json['Bastioni_Porta_Nuova_Viale_Crispi'][0])
print('\n')
print('Struttura json del traffico (Navigli):')
print(navigli_flow_json['Piazza_Castello'][0])
print('\n')
print('Struttura json del meteo (Bastioni):')
print(bastioni_weather_json['Bastioni_Porta_Nuova_Viale_Crispi'][0])
print('\n')
print('Struttura json del meteo (Navigli):')
print(navigli_weather_json['Piazza_Castello'][0])
'''


# Adesso occupiamoci dell'integrazione tra traffico e meteo, partendo dal traffico


# Aggiungiamo come campo ai json la circonvallazione di appartenenza, poi uniamo le vie

for street in bastioni_flow_json:
  l = len(bastioni_flow_json[street])
  for i in range(l):
    bastioni_flow_json[street][i]['ringRoad'] = 'Bastioni'

for street in navigli_flow_json:
  l = len(navigli_flow_json[street])
  for i in range(l):
    navigli_flow_json[street][i]['ringRoad'] = 'Navigli'

flow_json = {**bastioni_flow_json, **navigli_flow_json}


# 1. Cambiamo i valori del campo 'frc':
# FRC3: Strada secondaria
# FRC4: Strada di collegamento locale
#
# 2. Rinominiamo i campi frc e flowSegmentData in roadType e flowData
#
# 3. Aggiungiamo il campo 'LTZ', i.e. zona a traffico limitato:
# Navigli: Tutti i giorni, 20:00-7:00
# Bastioni: Lun-Ven, 7:30-19:30, esclusi festivi
# Tuttavia, la cerchia dei navigli è all'interno della cerchia dei bastioni.
# Pertanto, la ztl nei navigli è attiva anche quando lo è solo nei bastioni.
#
# 4. Aggiungiamo il campo 'flowConditions', i.e. condizioni generali del traffico.
# Ci basiamo sulla differenza percentuale tra la velocità di percorrenza senza 
# traffico (freeFlowSpeed) e la velocità di percorrenza attuale (currentSpeed).
# Scorrevole (Flowing): delta = 0-25%
# Moderato (Moderate): delta = 25-50%
# Congestionato (Congested): delta = 50-75%
# Bloccato (Blocked): delta = 75-100%

for street in flow_json:
  l = len(flow_json[street])
  for i in range(l):
    # 1.
    if(flow_json[street][i]['flowSegmentData']['frc'] == 'FRC3'):
        flow_json[street][i]['flowSegmentData']['frc'] = 'Secondary_Road'
    else:
        flow_json[street][i]['flowSegmentData']['frc'] = 'Local_Connecting_Road'
    # 2.
    flow_json[street][i]['roadType'] = flow_json[street][i]['flowSegmentData'].pop('frc')
    flow_json[street][i]['flowData'] = flow_json[street][i].pop('flowSegmentData')
    # 3.
    if flow_json[street][i]['ringRoad'] == 'Navigli':
      if(time(hour = 7, minute = 0) <= flow_json[street][i]['date'].time() <= time(hour = 20, minute = 0)):
        if(flow_json[street][i]['date'].date() == date(2022, 1, 1) or flow_json[street][i]['date'].date() == date(2022, 1, 2) or 
         flow_json[street][i]['date'].date() == date(2022, 1, 6) or flow_json[street][i]['date'].date() == date(2022, 1, 8) or 
         flow_json[street][i]['date'].date() == date(2022, 1, 9)):
          flow_json[street][i]['LTZ'] = False
        else:
          if(time(hour = 7, minute = 0) <= flow_json[street][i]['date'].time() < time(hour = 7, minute = 30) or
             time(hour = 19, minute = 30) <= flow_json[street][i]['date'].time() < time(hour = 20, minute = 0)):
            flow_json[street][i]['LTZ'] = False
          else:
            flow_json[street][i]['LTZ'] = True
      else:
          flow_json[street][i]['LTZ'] = True
    else:
      if(flow_json[street][i]['date'].date() == date(2022, 1, 1) or flow_json[street][i]['date'].date() == date(2022, 1, 2) or 
         flow_json[street][i]['date'].date() == date(2022, 1, 6) or flow_json[street][i]['date'].date() == date(2022, 1, 8) or 
         flow_json[street][i]['date'].date() == date(2022, 1, 9)):
         flow_json[street][i]['LTZ'] = False
      else:
        if(time(hour = 7, minute = 30) <= flow_json[street][i]['date'].time() <= time(hour = 19, minute = 30)):
          flow_json[street][i]['LTZ'] = True
        else:
          flow_json[street][i]['LTZ'] = False
    # 4.
    delta = flow_json[street][i]['flowData']['freeFlowSpeed'] - flow_json[street][i]['flowData']['currentSpeed']
    delta_perc = (delta/flow_json[street][i]['flowData']['freeFlowSpeed']) * 100
    if(delta_perc < 25):
      flow_json[street][i]['flowData']['flowConditions'] = 'Flowing'
    elif(25 <= delta_perc < 50):
      flow_json[street][i]['flowData']['flowConditions'] = 'Moderate'
    elif(50 <= delta_perc < 75):
      flow_json[street][i]['flowData']['flowConditions'] = 'Congested'
    else:
      flow_json[street][i]['flowData']['flowConditions'] = 'Blocked'


# Per vedere un esempio dei json

print('\n')
print('Struttura json del traffico:')
print(flow_json['Bastioni_Porta_Nuova_Viale_Crispi'][0])
print(flow_json['Piazza_Castello'][0])
print(flow_json['Bastioni_Porta_Nuova_Viale_Crispi'][-1])
print(flow_json['Piazza_Castello'][-1])



# Ora passiamo al meteo


# Aggiungiamo come campo ai json la circonvallazione di appartenenza, poi uniamo le vie

for street in bastioni_weather_json:
  l = len(bastioni_weather_json[street])
  for i in range(l):
    bastioni_weather_json[street][i]['ringRoad'] = 'Bastioni'

for street in navigli_weather_json:
  l = len(navigli_weather_json[street])
  for i in range(l):
    navigli_weather_json[street][i]['ringRoad'] = 'Navigli'

weather_json = {**bastioni_weather_json, **navigli_weather_json}


# Eliminiamo i campi ridondanti o irrilevanti e riorganizziamo il dizionario

for street in weather_json:
  l = len(weather_json[street])
  for i in range(l):
    weather_json[street][i]['temperature'] =  weather_json[street][i]['main']
    weather_json[street][i]['pressure'] =  weather_json[street][i]['temperature']['pressure']
    weather_json[street][i]['humidity'] =  weather_json[street][i]['temperature']['humidity']
    del  weather_json[street][i]['temperature']['pressure']
    del  weather_json[street][i]['temperature']['humidity']
    weather_json[street][i]['main'] =  weather_json[street][i]['weather']['main']
    del weather_json[street][i]['weather']
    del weather_json[street][i]['base']
    weather_json[street][i]['clouds'] = weather_json[street][i]['clouds']['all']
    weather_json[street][i]['sunrise'] =  weather_json[street][i]['sys']['sunrise']
    weather_json[street][i]['sunset'] =  weather_json[street][i]['sys']['sunset']
    del weather_json[street][i]['sys']
    del weather_json[street][i]['timezone'] 
    del weather_json[street][i]['id'] 
    del weather_json[street][i]['name'] 
    del weather_json[street][i]['cod']
    weather_json[street][i]['temperature']['feelsLike'] = weather_json[street][i]['temperature'].pop('feels_like')
    weather_json[street][i]['temperature']['tempMin'] = weather_json[street][i]['temperature'].pop('temp_min')
    weather_json[street][i]['temperature']['tempMax'] = weather_json[street][i]['temperature'].pop('temp_max')
   

# Per vedere un esempio dei json

print('\n')
print('Struttura json del meteo:')
print(weather_json['Bastioni_Porta_Nuova_Viale_Crispi'][0])
print(weather_json['Piazza_Castello'][0])
print(weather_json['Bastioni_Porta_Nuova_Viale_Crispi'][-1])
print(weather_json['Piazza_Castello'][-1])



# Ora dobbiamo integrare il dataset del traffico col dataset del meteo


final_json = {}


# Riorganizziamo i dati 

for street in flow_json:  
  l = len(flow_json[street])
  final_json[street] = []
  for i in range(l):
    date = flow_json[street][i]['date']
    ringRoad = flow_json[street][i]['ringRoad']
    roadType = flow_json[street][i]['roadType']
    LTZ = flow_json[street][i]['LTZ']
    traffic = flow_json[street][i]['flowData']
    final_json[street].append({'date': date, 'ringRoad': ringRoad, 'roadType': roadType, 'LTZ': LTZ, 'traffic': traffic})


# Assicuriamoci che le differenze tra le lunghezze di meteo e traffico siano minori di 8,
# in modo da definire in sicurezza un intorno di 16 record in cui ricercare 'lastUpdate'

for street in flow_json:
  if(len(flow_json[street]) - len(weather_json[street]) > 8):
    print('Intorno superato: '+ street)


# Aggiungiamo i dati del meteo in maniera sincronizzata:
# minimizziamo la differenza tra il campo 'lastUpdate' di weather_json e 'date' di final_json

for street in final_json:
  l1 = len(final_json[street])
  l2 = len(weather_json[street])
  for i in range(l1):
    optimal = abs(weather_json[street][0]['lastUpdate'] - final_json[street][i]['date']).total_seconds()
    optimal_index = 0
    # Ricerca del valore ottimo di 'lastUpdate' in un intorno di 16 record rispetto al traffico
    if(l1 - i <= 8):
      start = l1 - 16
      end = l1
    elif(i < 7):
      start = 0
      end = 16
    else:
      start = i - 8
      end = i + 8
    if(end >= l2):
      end = l2
    for j in range(start, end):
      delta = abs(weather_json[street][j]['lastUpdate'] - final_json[street][i]['date']).total_seconds()
      if (delta < optimal):
        optimal = delta
        optimal_index = j
    weather = {}
    weather['main'] = weather_json[street][optimal_index]['main']
    weather['clouds'] = weather_json[street][optimal_index]['clouds']
    weather['wind'] = weather_json[street][optimal_index]['wind']
    weather['temperature'] = weather_json[street][optimal_index]['temperature']
    weather['pressure'] = weather_json[street][optimal_index]['pressure']
    weather['humidity'] = weather_json[street][optimal_index]['humidity']
    weather['visibility'] = weather_json[street][optimal_index]['visibility']
    weather['sunrise'] = weather_json[street][optimal_index]['sunrise']
    weather['sunset'] = weather_json[street][optimal_index]['sunset']
    weather['lastUpdate'] = weather_json[street][optimal_index]['lastUpdate']
    final_json[street][i]['weather'] = weather


# Occupiamoci delle informazioni temporali (campo datetime)
# (Spezziamo i campi in data e ora in modo da agevolare le query sui dati)

minutes = np.array([0, 10, 20, 30, 40, 50])

for street in flow_json:
  l = len(final_json[street])
  for i in range(l):
    dt = final_json[street][i]['date']
    dt2 = final_json[street][i]['weather']['lastUpdate']

    # Creiamo il campo datetime
    final_json[street][i]['dateTime'] = {}

    # Aggiungiamo le informazioni relative all'orario del traffico
    final_json[street][i]['dateTime']['trafficDate'] = datetime.strftime(dt, '%Y-%m-%d')
    final_json[street][i]['dateTime']['effectiveTrafficTime'] = datetime.strftime(dt, '%H:%M:%S')
    
    # Aggiungiamo le informazioni relative all'orario del meteo
    final_json[street][i]['dateTime']['weatherDate'] = datetime.strftime(dt2, '%Y-%m-%d')
    final_json[street][i]['dateTime']['effectiveWeatherTime'] = datetime.strftime(dt2, '%H:%M:%S')

    if minutes[abs(minutes-dt.minute).argmin()] == 0:
      final_json[street][i]['dateTime']['time'] = datetime.strftime(dt, '%H')+':'+str(minutes[abs(minutes-dt.minute).argmin()])+'0:00'
    else:
      final_json[street][i]['dateTime']['time'] = datetime.strftime(dt, '%H')+':'+str(minutes[abs(minutes-dt.minute).argmin()])+':00'
    
    # Eliminiamo i campi vecchi
    del final_json[street][i]['date']
    del final_json[street][i]['weather']['lastUpdate']


# Per vedere un esempio dei json

print('\n')
print('STRUTTURA FINALE:')
print(final_json['Bastioni_Porta_Nuova_Viale_Crispi'][0])
print(final_json['Bastioni_Porta_Nuova_Viale_Crispi'][-1])


# Salvataggio in json
'''
for street in final_json:
  for i in range (len(final_json[street])):
    day = final_json[street][i]['dateTime']['date']
    hour = final_json[street][i]['dateTime']['time'][:2] + '_' + final_json[street][i]['dateTime']['time'][3:5]
    with open('DataMan/DB/' + street + '_' + day + '_' + hour + '.json', 'w') as f:
      jsonobj = json.dumps(final_json[street][i], indent = 4, default = str) 
      f.write(jsonobj)
'''
# Out:
# Struttura json del traffico:
# {'date': Timestamp('2021-12-28 00:01:25'), 'street': 'Bastioni_Porta_Nuova_Viale_Crispi', 'ringRoad': 'Bastioni', 'roadType': 'Secondary_Road', 'flowData': {'currentSpeed': 26, 'freeFlowSpeed': 26, 'currentTravelTime': 108, 'freeFlowTravelTime': 108, 'confidence': 1, 'roadClosure': False, 'flowConditions': 'Flowing'}, 'LTZ': False}
# {'date': Timestamp('2021-12-28 00:01:21'), 'street': 'Piazza_Castello', 'ringRoad': 'Navigli', 'roadType': 'Local_Connecting_Road', 'flowData': {'currentSpeed': 21, 'freeFlowSpeed': 21, 'currentTravelTime': 36, 'freeFlowTravelTime': 36, 'confidence': 1, 'roadClosure': False, 'flowConditions': 'Flowing'}, 'LTZ': True}
# ...

# %% [markdown]
# # Data storage

# %%
# Importiamo le librerie 
import os
import pymongo
from pymongo import MongoClient
import json
# Path della cartella contenente i file json
path = "C:/Users/greta/Downloads/DB/DB"

# Cambiamo la directory
os.chdir(path)

# Connessione con MongoDB Compass
client = MongoClient('localhost', 27017)
db= client.get_database('DataMan_database')
dataman=db.DataMan


# Lettura dei file 
def read_text_file(file_path):
	with open(file_path, 'r') as f:
		f = f.read()
		f = json.loads(str(f))
		record = dataman.insert_one(f)


# Iterazione di tutti i file
for file in os.listdir():
	# Verifica il formato dei file
	if file.endswith(".json"):
		file_path = f"{path}\{file}"


		# Richiamo read text file function
		read_text_file(file_path)

# %% [markdown]
# # Data quality

# %%
#Importiamo le librerie
import os
import pandas as pd
import pymongo
from pymongo import MongoClient
import json

#Connessione con MongoDB Compass
client = MongoClient('localhost', 27017)
db= client.get_database('DataMan_database')
dataman=db.DataMan

#query
#Utilizzo di "aggregate" per vedere se mancano record in vie
agg_result= dataman.aggregate(
[{
    "$group": {
    "_id": "$street",
    "n_record": {"$sum": 1}
}
    },
    {
        "$sort":{"n_record":1}
    }]
)

agg_result=list(agg_result)
prova2=[]
for i in agg_result:
    i['percentual']=i['n_record']/2016*(100)
    i['percentual']=round(i['percentual'], 2)

    prova2.append(i)
    
# Utilizzo di "aggregate" per vedere se mancano record in ore
agg_result1= dataman.aggregate(
[{
    "$group": {
    "_id": "$dateTime.time",
    "n_record": {"$sum": 1}
}
    },
    {
        "$sort":{"n_record":1}
    }]
)
agg_result1=list(agg_result1)
prova=[]
prova2=[]

for i in agg_result1:
    i['percentual']=i['n_record']/336*(100)
    i['percentual'] = round(i['percentual'], 2)
    prova.append(i)

for i in agg_result:
    prova2.append(i)

df=pd.json_normalize(prova)
df.to_csv('completezza_oraria.csv')


df=pd.json_normalize(prova2)
df.to_csv('completezza_per_via.csv')
